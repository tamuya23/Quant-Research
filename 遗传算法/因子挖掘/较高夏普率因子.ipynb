# %% [markdown]
# ## mkt10

# %% [markdown]
# add(log(turnover_score_ts_std), rank_2_corr_hv10) \
# ![image.png](attachment:bcf22168-03f1-42b2-970e-5e151c4423e3.png)

# %% [markdown]
# -log(log(turnover_score_ts_std))\
# ![image.png](attachment:5b0cea4c-cbf8-4efc-aca7-76f78664438e.png)

# %% [markdown]
# -add(max_(amt_std, a15), ts_min5(h_rankv_corr_10))\
# ![image.png](attachment:f8e0d098-a442-42b3-8003-be423ee85e39.png)

# %% [markdown]
# sub(mkv, turnoverf)\
# ![image.png](attachment:9673bbe2-e9e9-4abf-abcd-063c50347388.png)

# %% [markdown]
# add(ll30, bias15)\
# ![image.png](attachment:7d2326b9-c854-42b1-b131-6b80622d5bde.png)

# %% [markdown]
# ## mkt20

# %% [markdown]
# -sub(turnoverf_mean, div(peak_count_vol_RC, cross_std10adj)) \
# ![image.png](attachment:68d9b3e2-361d-4e98-afd1-e26aecdf5e14.png)

# %% [markdown]
# -sub(SMTR, inv(turnoverf))\
# ![image.png](attachment:0bc557e8-118d-4f1b-bf71-d6b40dae9aef.png)

# %% [markdown]
# add(ILLIQ, add(sub, turnover))\
# ![image.png](attachment:122c7c1c-113e-4151-9ef2-0625059694ff.png)

# %% [markdown]
# add(min_(min_(bias5, STR), max_(ll20, CSK_XYY_UP_DOWN_120D_RC)), log(SMTR))\
# ![image.png](attachment:18dc0ec2-95a8-4b3a-ab81-6dfe88f26f07.png)

# %% [markdown]
# -mul(STR, turnover_scale_z)\
# ![image.png](attachment:25794413-26ce-48d7-856a-8e2e2edd91fc.png)

# %% [markdown]
# ## mkt1

# %% [markdown]
# -log(sub(ts_std5(ts_skew10(ts_corr5(peak_count_vol_RC, turnover_score_ts_mean))), sqrt(cross_std10adj)))\
# ![image.png](attachment:1a3b08c4-a1b5-4ffd-bd5c-d435a6590d29.png)

# %% [markdown]
# -sub(sqrt(up_KURS), sqrt(sub(lhret, turnoverf_std)))\
# ![image.png](attachment:cd51a7e2-649d-4a77-a315-611fa52f6b97.png)

# %% [markdown]
# sqrt(lcret)\
# ![image.png](attachment:e1f44a42-cbf9-4ae8-9558-c6e594b8aeff.png)

# %% [markdown]
# ## 最小100

# %% [markdown]
# add(l_mkv, add(ll15, mkv))\
# ![image.png](attachment:cbe56679-c998-456d-8c5f-ed96a7db5d9a.png)

# %% [markdown]
# add(rank(mkv), ILLIQ)\
# ![image.png](attachment:d1fba0b0-0660-475b-87d2-80b59719272b.png)

# %% [markdown]
# add(add(log(amt_std), ILLIQ), turnoverf_std)\
# ![image.png](attachment:f9cf10cc-65ce-475e-b538-87a8e70ea7c2.png)

# %% [markdown]
# add(abs(scr), ILLIQ)\
# ![image.png](attachment:0ee92078-b383-450a-ab87-20635064f3e2.png)

# %% [markdown]
# add(add(nl_mkv, ILLIQ), turnoverf_std)\
# ![image.png](attachment:ad5ea82b-d5f5-4e07-b145-253382cc71a9.png)

# %% [markdown]
# add(amt_score0, roc15)\

# %% [markdown]
# ## 标准化后10

# %% [markdown]
# sub(up_KURS, hcret)\
# ![image.png](attachment:2f5b548d-f02e-474f-9f45-7813fe35296b.png)

# %% [markdown]
# min_(up_KURS, delay5(a5))\
# ![image.png](attachment:6a13deaa-8968-4085-bc8b-0ba9815d05d9.png)

# %% [markdown]
# add(turnover_mean, add(up_KURS, ivr))\
# ![image.png](attachment:ac3bbff2-f562-412d-b3b7-1e2ba0f70d1c.png)

# %% [markdown]
#  add(turnover_mean, up_KURS)\
#  ![image.png](attachment:e65204bd-1855-4dc1-b12d-625c7bea728b.png)

# %% [markdown]
# rank/count处理后

# %% [markdown]
# max_(max_(up_plus_down_KURS, SMTR), max_(bias15, vol_std))\
# filter0\
# ![image.png](attachment:33c865e8-ed69-44e9-8970-e27465176258.png)

# %%
#add(amt_score0, roc15)
